# %% [markdown]
# # Weighted phase space samples
# This tutrial shows how to get histograms corresponding to a DelitzModel and take into account detection efficiency

# %%
import sys
sys.path.append("../lib/")

from DalitzPhaseSpace import DalitzPhaseSpace
from PhspGen import PhspGen
from DalitzModel import DalitzModel
from Efficiency import Detector

# %%
from PlotUtility import projections

# %%
phsp = DalitzPhaseSpace(0.511, 0.139, 0.139, 1.865)
phspGen = PhspGen(phsp)
sample = phspGen('AB', 'BC', 10**6, True)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
projections(sample, 'steelblue', True)
plt.show()

# %%
model = DalitzModel(0.511, 0.139, 0.139, 1.865)
model.add_bw('rho(770)', .770, .1490, 1, 'BC')
model.add_bw('K*', .89166, 0.0508, 1, 'AB', 0.638*np.exp(1j*np.radians(133.2)))
weights = abs(model(sample))**2

# %%
projections(sample, 'steelblue', True, 0.6, weights)
plt.show()
