# %%
import sys
sys.path.append("../lib/")

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors, ticker

from DalitzModel import *
from BWRes import *

# %matplotlib inline
plt.rc('animation', html='html5')
plt.rc('text', usetex=True)
plt.rc('font', size=18)

# %%
degtorad = np.pi / 180.

# %%
def plot_ddist(mab, mbc, bins=200, num=None):
    """ Scatter plot of Dalitz distribution """
    fig = plt.figure(num=num, figsize=(8,6))
    ax = fig.add_subplot(111)
    hist = ax.hist2d(mab, mbc, bins=bins, cmap=plt.cm.PuBu)
    fig.colorbar(hist[3], ax=ax, pad=0.02)

# %%
def phsp_edge(phsp, rtype1, rtype2):
    """ Calculate phase space edges """
    mr1_min, mr1_max = phsp.mass_sq_range[rtype1]
    mr1_space = np.linspace(mr1_min, mr1_max, 1000)
    mr2_mins, mr2_maxs = phsp.mr_sq_range(rtype2, mr1_space, rtype1)
    mr1 = np.concatenate([mr1_space, mr1_space[::-1]])
    mr2 = np.concatenate([mr2_mins, mr2_maxs[::-1]])
    return [mr1, mr2]

# %%
def show_phase_space(phsp, rtype1, rtype2, num=None, color=None):
    """ Plot phase space edge """
    if color is None:
        color = 'blue'
    mr1, mr2 = phsp_edge(phsp, rtype1, rtype2)
    mr1_range = max(mr1) - min(mr1)
    mr2_range = max(mr2) - min(mr2)
    fig = plt.figure(num=num)
    plt.plot(mr1, mr2, linestyle='-', color=color)
    plt.gca().set_xlabel(r'$m^{2}_{\mathrm{' + rtype1 + r'}}\ (GeV^{2}/c^{4})$')
    plt.gca().set_ylabel(r'$m^{2}_{\mathrm{' + rtype2 + r'}}\ (GeV^{2}/c^{4})$')
    plt.axis('equal')
    plt.tight_layout()
    plt.xlim(0, 1.05*max(mr1))
    plt.ylim(0, 1.05*max(mr2))

# %%
model = DalitzModel(.475, .135, .135, 1.865)
model.add_bw('rho(770)', .770, .1490, 1, 'BC')
model.add_bw('K*', .89166, 0.0508, 1, 'AB', 0.638*np.exp(1j*133.2*degtorad))

# %%
rtype1, rtype2 = 'AB', 'BC'
mab_sq, mbc_sq = model.mcmc_sample(10**6, rtype1, rtype2)

# %%
print model
# Out:
# Phase space D -> ABC, where
#  mD = 1.865, mA = 0.475, mB = 0.135, mC = 0.135

# %%
def plot_density_countours(msq1g, msq2g, dens, num=None, figsize=None, nlevels=25, cmap=plt.cm.PuBu):
    fig = plt.figure(num=num, figsize=figsize)
    levels = np.linspace(0, max(dens.flatten()), nlevels)
    CS = plt.contourf(msq1g, msq2g, dens, cmap=cmap, levels=levels)
#     CS = plt.contour(msq1g, msq2g, dens, cmap=cmap, levels=levels)
    plt.colorbar(CS)

# %%
msq1g, msq2g, dens = model.grid_dens('AB', 'BC', 250)
plot_density_countours(msq1g, msq2g, dens, 6, (10, 6))
show_phase_space(model, 'AB', 'BC', 6, 'blue')

# %%
mab_sq_range = model.mass_sq_range['AB']
mab_sq_range
# Out:
# [0.37209999999999999, 2.9929000000000001]

# %%
# dens = model.density(1., 1.)
# dens

# %%
majorant = model.assess_majorant()
majorant
# Out:
# 238.32778097342461

# %%
rtype1, rtype2 = 'AB', 'BC'
mab_sq, mbc_sq = model.sample(10**6, rtype1, rtype2)
# Out:
# 43645 events generated
# 86965 events generated
# 130334 events generated
# 173696 events generated
# 217022 events generated
# 260055 events generated
# 303317 events generated
# 346215 events generated
# 389444 events generated
# 432734 events generated
# 476423 events generated
# 519485 events generated
# 562885 events generated
# 606204 events generated
# 649715 events generated
# 692976 events generated
# 736372 events generated
# 779743 events generated
# 823302 events generated
# 866473 events generated
# 910037 events generated
# 953423 events generated
# 996577 events generated
# 1040277 events generated

# %%
plot_ddist(mab_sq, mbc_sq, 400, 5)
show_phase_space(model, rtype1, rtype2, 5)

# %%
mac_sq = model.third_mass_sq(mab_sq, mbc_sq)
plot_ddist(mab_sq, mac_sq, 400, 5)
show_phase_space(model, 'AB', 'AC', 5)

# %%
plt.hist(np.sqrt(mab_sq), bins=100);

# %%
plt.hist(np.sqrt(mac_sq), bins=100);

# %%
plt.hist(np.sqrt(mbc_sq), bins=100);

# %% [markdown]
# ## Animated interference

# %%
from matplotlib import animation

# %%
# FIG = plt.figure(num=9, figsize=(10, 6))
# AXES = plt.axes()
# show_phase_space(model, 'AB', 'BC', 9, 'blue')
# plt.grid()
# plt.title(r'$\rho(770)$ -- $K^*(892)$ interference')
# plt.close()

# %%
import types
def setvisible(self,vis):
    for c in self.collections: c.set_visible(vis)
def setanimated(self,ani):
    for c in self.collections: c.set_animated(ani)

# %%
def animate(i):
    """ Init frame """
    plt.figure(num=9)
    model.rdict['K*']['ampl'] *= np.exp(1j * np.pi / 100)
    dens = model.density(msq1g, msq2g, 'AB', 'BC')
    levels = np.linspace(0, max(dens.flatten()), 25)
#     plt.title(r'$\rho(770)$ -- $K^*(892)$ interference, K^* phase = {}'.format(np.angle(model.rdict['K*']['ampl'])))
    cont = AXES.contourf(msq1g, msq2g, dens, cmap=plt.cm.PuBu, levels=levels)
    text = 'title=' + str(i)
    te = AXES.text(90,90,str(text))
    an = AXES.annotate(str(text), xy=(0.45, 1.05), xycoords='axes fraction')
    AXES.colorbar(cont)
    cont.set_visible = types.MethodType(setvisible, cont)
    cont.set_animated = types.MethodType(setanimated, cont)
    return [cont,te,an], str(i)

# %%
FIG = plt.figure(num=9, figsize=(9, 6))
AXES = plt.axes()
show_phase_space(model, 'AB', 'BC', 9, 'blue')
plt.grid()
plt.title(r'$\rho(770)$ -- $K^*(892)$ interference')
plt.close()

# %%
ims = []
for i in range(200):
    model.rdict['K*']['ampl'] *= np.exp(1j * np.pi / 100)
    dens = model.density(msq1g, msq2g, 'AB', 'BC')
    levels = np.linspace(0, max(dens.flatten()), 25)
    cont = AXES.contourf(msq1g, msq2g, dens, cmap=plt.cm.PuBu, levels=levels)
#     plt.colorbar(cont)
    add_arts = cont.collections
    text = ''
    te = AXES.text(90,90,str(text))
    an = AXES.annotate(str(text), xy=(0.45, 1.05), xycoords='axes fraction')
    ims.append(add_arts + [te,an])
    print 'frame {} / {}'.format(i, 200)
# Out:
# frame 0 / 200
# frame 1 / 200
# frame 2 / 200
# frame 3 / 200
# frame 4 / 200
# frame 5 / 200
# frame 6 / 200
# frame 7 / 200
# frame 8 / 200
# frame 9 / 200
# frame 10 / 200
# frame 11 / 200
# frame 12 / 200
# frame 13 / 200
# frame 14 / 200
# frame 15 / 200
# frame 16 / 200
# frame 17 / 200
# frame 18 / 200
# frame 19 / 200
# frame 20 / 200
# frame 21 / 200
# frame 22 / 200
# frame 23 / 200
# frame 24 / 200
# frame 25 / 200
# frame 26 / 200
# frame 27 / 200
# frame 28 / 200
# frame 29 / 200
# frame 30 / 200
# frame 31 / 200
# frame 32 / 200
# frame 33 / 200
# frame 34 / 200
# frame 35 / 200
# frame 36 / 200
# frame 37 / 200
# frame 38 / 200
# frame 39 / 200
# frame 40 / 200
# frame 41 / 200
# frame 42 / 200
# frame 43 / 200
# frame 44 / 200
# frame 45 / 200
# frame 46 / 200
# frame 47 / 200
# frame 48 / 200
# frame 49 / 200
# frame 50 / 200
# frame 51 / 200
# frame 52 / 200
# frame 53 / 200
# frame 54 / 200
# frame 55 / 200
# frame 56 / 200
# frame 57 / 200
# frame 58 / 200
# frame 59 / 200
# frame 60 / 200
# frame 61 / 200
# frame 62 / 200
# frame 63 / 200
# frame 64 / 200
# frame 65 / 200
# frame 66 / 200
# frame 67 / 200
# frame 68 / 200
# frame 69 / 200
# frame 70 / 200
# frame 71 / 200
# frame 72 / 200
# frame 73 / 200
# frame 74 / 200
# frame 75 / 200
# frame 76 / 200
# frame 77 / 200
# frame 78 / 200
# frame 79 / 200
# frame 80 / 200
# frame 81 / 200
# frame 82 / 200
# frame 83 / 200
# frame 84 / 200
# frame 85 / 200
# frame 86 / 200
# frame 87 / 200
# frame 88 / 200
# frame 89 / 200
# frame 90 / 200
# frame 91 / 200
# frame 92 / 200
# frame 93 / 200
# frame 94 / 200
# frame 95 / 200
# frame 96 / 200
# frame 97 / 200
# frame 98 / 200
# frame 99 / 200
# frame 100 / 200
# frame 101 / 200
# frame 102 / 200
# frame 103 / 200
# frame 104 / 200
# frame 105 / 200
# frame 106 / 200
# frame 107 / 200
# frame 108 / 200
# frame 109 / 200
# frame 110 / 200
# frame 111 / 200
# frame 112 / 200
# frame 113 / 200
# frame 114 / 200
# frame 115 / 200
# frame 116 / 200
# frame 117 / 200
# frame 118 / 200
# frame 119 / 200
# frame 120 / 200
# frame 121 / 200
# frame 122 / 200
# frame 123 / 200
# frame 124 / 200
# frame 125 / 200
# frame 126 / 200
# frame 127 / 200
# frame 128 / 200
# frame 129 / 200
# frame 130 / 200
# frame 131 / 200
# frame 132 / 200
# frame 133 / 200
# frame 134 / 200
# frame 135 / 200
# frame 136 / 200
# frame 137 / 200
# frame 138 / 200
# frame 139 / 200
# frame 140 / 200
# frame 141 / 200
# frame 142 / 200
# frame 143 / 200
# frame 144 / 200
# frame 145 / 200
# frame 146 / 200
# frame 147 / 200
# frame 148 / 200
# frame 149 / 200
# frame 150 / 200
# frame 151 / 200
# frame 152 / 200
# frame 153 / 200
# frame 154 / 200
# frame 155 / 200
# frame 156 / 200
# frame 157 / 200
# frame 158 / 200
# frame 159 / 200
# frame 160 / 200
# frame 161 / 200
# frame 162 / 200
# frame 163 / 200
# frame 164 / 200
# frame 165 / 200
# frame 166 / 200
# frame 167 / 200
# frame 168 / 200
# frame 169 / 200
# frame 170 / 200
# frame 171 / 200
# frame 172 / 200
# frame 173 / 200
# frame 174 / 200
# frame 175 / 200
# frame 176 / 200
# frame 177 / 200
# frame 178 / 200
# frame 179 / 200
# frame 180 / 200
# frame 181 / 200
# frame 182 / 200
# frame 183 / 200
# frame 184 / 200
# frame 185 / 200
# frame 186 / 200
# frame 187 / 200
# frame 188 / 200
# frame 189 / 200
# frame 190 / 200
# frame 191 / 200
# frame 192 / 200
# frame 193 / 200
# frame 194 / 200
# frame 195 / 200
# frame 196 / 200
# frame 197 / 200
# frame 198 / 200
# frame 199 / 200

# %%
ani = animation.ArtistAnimation(FIG, ims, interval=20, blit=True)
ani
# Out:
# <video width="1000.0" height="600.0" controls autoplay loop>
#   <source type="video/mp4" src="...
