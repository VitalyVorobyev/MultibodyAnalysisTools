# %%
import sys
sys.path.append("../lib/")

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors, ticker

from DalitzModel import *
from BWRes import *

# %matplotlib inline
plt.rc('animation', html='html5')
plt.rc('text', usetex=True)
plt.rc('font', size=18)

# %%
degtorad = np.pi / 180.

# %%
def plot_ddist(mab, mbc, bins=200, num=None):
    """ Scatter plot of Dalitz distribution """
    fig = plt.figure(num=num, figsize=(8,6))
    ax = fig.add_subplot(111)
    hist = ax.hist2d(mab, mbc, bins=bins, cmap=plt.cm.PuBu)
    fig.colorbar(hist[3], ax=ax, pad=0.02)

# %%
def phsp_edge(phsp, rtype1, rtype2):
    """ Calculate phase space edges """
    mr1_min, mr1_max = phsp.mass_sq_range[rtype1]
    mr1_space = np.linspace(mr1_min, mr1_max, 1000)
    mr2_mins, mr2_maxs = phsp.mr_sq_range(rtype2, mr1_space, rtype1)
    mr1 = np.concatenate([mr1_space, mr1_space[::-1]])
    mr2 = np.concatenate([mr2_mins, mr2_maxs[::-1]])
    return [mr1, mr2]

# %%
def show_phase_space(phsp, rtype1, rtype2, num=None, color=None):
    """ Plot phase space edge """
    if color is None:
        color = 'blue'
    mr1, mr2 = phsp_edge(phsp, rtype1, rtype2)
    mr1_range = max(mr1) - min(mr1)
    mr2_range = max(mr2) - min(mr2)
    fig = plt.figure(num=num)
    plt.plot(mr1, mr2, linestyle='-', color=color)
    plt.gca().set_xlabel(r'$m^{2}_{\mathrm{' + rtype1 + r'}}\ (GeV^{2}/c^{4})$')
    plt.gca().set_ylabel(r'$m^{2}_{\mathrm{' + rtype2 + r'}}\ (GeV^{2}/c^{4})$')
    plt.axis('equal')
    plt.tight_layout()
    plt.xlim(0, 1.05*max(mr1))
    plt.ylim(0, 1.05*max(mr2))

# %%
model = DalitzModel(.475, .135, .135, 1.865)
model.add_bw('rho(770)', .770, .1490, 1, 'BC')
model.add_bw('K*', .89166, 0.0508, 1, 'AB', 0.638*np.exp(1j*133.2*degtorad))

# %%
print model
# Out:
# Phase space D -> ABC, where
#  mD = 1.865, mA = 0.475, mB = 0.135, mC = 0.135

# %%
def plot_density_countours(msq1g, msq2g, dens, num=None, figsize=None, nlevels=25, cmap=plt.cm.PuBu):
    fig = plt.figure(num=num, figsize=figsize)
    levels = np.linspace(0, max(dens.flatten()), nlevels)
    CS = plt.contourf(msq1g, msq2g, dens, cmap=cmap, levels=levels)
    plt.colorbar(CS)

# %%
msq1g, msq2g, dens = model.grid_dens('AB', 'BC', 250)
plot_density_countours(msq1g, msq2g, dens, 6, (10, 6))
show_phase_space(model, 'AB', 'BC', 6, 'blue')

# %%
mab_sq_range = model.mass_sq_range['AB']
mab_sq_range
# Out:
# [0.37209999999999999, 2.9929000000000001]

# %%
dens = model.density(1., 1.)
dens
# Out:
# 4.2397868816228348

# %%
majorant = model.assess_majorant()
majorant
# Out:
# 238.36979907324175

# %%
rtype1, rtype2 = 'AB', 'BC'
mab_sq, mbc_sq = model.sample(10**6, rtype1, rtype2)
# Out:
# 43404 events generated
# 86518 events generated
# 130028 events generated
# 173620 events generated
# 216724 events generated
# 259869 events generated
# 302980 events generated
# 346536 events generated
# 389470 events generated
# 432900 events generated
# 475955 events generated
# 519500 events generated
# 562494 events generated
# 605850 events generated
# 648680 events generated
# 691686 events generated
# 734892 events generated
# 778414 events generated
# 821759 events generated
# 864963 events generated
# 908092 events generated
# 951319 events generated
# 994706 events generated
# 1038181 events generated

# %%
plot_ddist(mab_sq, mbc_sq, 400, 5)
show_phase_space(model, rtype1, rtype2, 5)

# %%
mac_sq = model.third_mass_sq(mab_sq, mbc_sq)
plot_ddist(mab_sq, mac_sq, 400, 5)
show_phase_space(model, 'AB', 'AC', 5)

# %%
plt.hist(np.sqrt(mab_sq), bins=100);

# %%
plt.hist(np.sqrt(mac_sq), bins=100);

# %%
plt.hist(np.sqrt(mbc_sq), bins=100);

# %% [markdown]
# ## Animated interference

# %%
from matplotlib import animation

# %%
FIG = plt.figure(num=9, figsize=(10, 6))
AXES = plt.axes()
show_phase_space(model, 'AB', 'BC', 9, 'blue')
plt.grid()
plt.title(r'$\rho(770)$ -- $K^*(892)$ interference')
# plt.close()

# %%
def animate(i):
    """ Init frame """
    plt.figure(num=9)
    model.rdict['K*']['ampl'] *= np.exp(1j * np.pi / 100)
    dens = model.density(msq1g, msq2g, 'AB', 'BC')
    levels = np.linspace(0, max(dens.flatten()), 25)
#     plt.title(r'$\rho(770)$ -- $K^*(892)$ interference, K^* phase = {}'.format(np.angle(model.rdict['K*']['ampl'])))
    cont = AXES.contourf(msq1g, msq2g, dens, cmap=plt.cm.PuBu, levels=levels)
    return cont,

# %%
anim = animation.FuncAnimation(FIG, animate, frames=200, interval=20, blit=True)
anim
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
#     312             return None
#     313         else:
#
# /usr/lib/python2.7/dist-packages/matplotlib/animation.pyc in _repr_html_(self)
#    1007         fmt = rcParams['animation.html']
#    1008         if fmt == 'html5':
# -> 1009             return self.to_html5_video()
#    1010
#    1011
#
# /usr/lib/python2.7/dist-packages/matplotlib/animation.pyc in to_html5_video(self)
#     981                                 bitrate=rcParams['animation.bitrate'],
#     982                                 fps=1000. / self._interval)
# --> 983                 self.save(f.name, writer=writer)
#     984
#     985             # Now open and base64 encode
#
# /usr/lib/python2.7/dist-packages/matplotlib/animation.pyc in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#     830                 for anim in all_anim:
#     831                     # Clear the initial frame
# --> 832                     anim._init_draw()
#     833                 for data in zip(*[a.new_saved_frame_seq()
#     834                                   for a in all_anim]):
#
# /usr/lib/python2.7/dist-packages/matplotlib/animation.pyc in _init_draw(self)
#    1219         # artists.
#    1220         if self._init_func is None:
# -> 1221             self._draw_frame(next(self.new_frame_seq()))
#    1222
#    1223         else:
#
# /usr/lib/python2.7/dist-packages/matplotlib/animation.pyc in _draw_frame(self, framedata)
#    1241         # Call the func with framedata and args. If blitting is desired,
#    1242         # func needs to return a sequence of any artists that were modified.
# -> 1243         self._drawn_artists = self._func(framedata, *self._args)
#    1244         if self._blit:
#    1245             if self._drawn_artists is None:
#
# <ipython-input-42-fe3a2cbafff8> in animate(i)
#       6     levels = np.linspace(0, max(dens.flatten()), 25)
#       7 #     plt.title(r'$\rho(770)$ -- $K^*(892)$ interference, K^* phase = {}'.format(np.angle(model.rdict['K*']['ampl'])))
# ----> 8     cont, = AXES.contourf(msq1g, msq2g, dens, cmap=plt.cm.PuBu, levels=levels)
#       9     return cont,
#
# TypeError: 'QuadContourSet' object is not iterable

# %%
ims = []
for i in range(200):
    model.rdict['K*']['ampl'] *= np.exp(1j * np.pi / 100)
    dens = model.density(msq1g, msq2g, 'AB', 'BC')
    levels = np.linspace(0, max(dens.flatten()), 25)
    cont = AXES.contourf(msq1g, msq2g, dens, cmap=plt.cm.PuBu, levels=levels)
ims.append(cont)

# %%
ani = animation.ArtistAnimation(FIG, ims, interval=20, blit=True)

# %%
ani
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
#     312             return None
#     313         else:
#
# /usr/lib/python2.7/dist-packages/matplotlib/animation.pyc in _repr_html_(self)
#    1007         fmt = rcParams['animation.html']
#    1008         if fmt == 'html5':
# -> 1009             return self.to_html5_video()
#    1010
#    1011
#
# /usr/lib/python2.7/dist-packages/matplotlib/animation.pyc in to_html5_video(self)
#     981                                 bitrate=rcParams['animation.bitrate'],
#     982                                 fps=1000. / self._interval)
# --> 983                 self.save(f.name, writer=writer)
#     984
#     985             # Now open and base64 encode
#
# /usr/lib/python2.7/dist-packages/matplotlib/animation.pyc in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#     830                 for anim in all_anim:
#     831                     # Clear the initial frame
# --> 832                     anim._init_draw()
#     833                 for data in zip(*[a.new_saved_frame_seq()
#     834                                   for a in all_anim]):
#
# /usr/lib/python2.7/dist-packages/matplotlib/animation.pyc in _init_draw(self)
#    1098         figs = set()
#    1099         for f in self.new_frame_seq():
# -> 1100             for artist in f:
#    1101                 artist.set_visible(False)
#    1102                 artist.set_animated(self._blit)
#
# TypeError: 'QuadContourSet' object is not iterable
